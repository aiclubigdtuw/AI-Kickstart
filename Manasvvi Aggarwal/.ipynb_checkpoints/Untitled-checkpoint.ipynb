# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
info = pd.read_csv(r'train.csv')

# %%
info
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.27               0                  0.00
# 1              1                  0.00               2                  0.00
# 2              1                  0.10               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.00               2                  0.00
# ..           ...                   ...             ...                   ...
# 571            1                  0.55               1                  0.44
# 572            1                  0.38               1                  0.33
# 573            1                  0.57               2                  0.00
# 574            1                  0.57               1                  0.00
# 575            1                  0.27               1                  0.00
#
# ...

# %%
info.describe()
# Out:
#        profile pic  nums/length username  fullname words  \
# count   576.000000            576.000000      576.000000
# mean      0.701389              0.163837        1.460069
# std       0.458047              0.214096        1.052601
# min       0.000000              0.000000        0.000000
# 25%       0.000000              0.000000        1.000000
# 50%       1.000000              0.000000        1.000000
# 75%       1.000000              0.310000        2.000000
# max       1.000000              0.920000       12.000000
#
#        nums/length fullname  name==username  description length  external URL  \
# count            576.000000      576.000000          576.000000    576.000000
# mean               0.036094        0.034722           22.623264      0.116319
# std                0.125121        0.183234           37.702987      0.320886
# min                0.000000        0.000000            0.000000      0.000000
# ...

# %%
sns.displot(info['description length'], kde=False)

# %%
info.from_records(data=info, index="profile pic")
# Out:
#              nums/length username  fullname words  nums/length fullname  \
# profile pic
# 1                            0.27               0                  0.00
# 1                            0.00               2                  0.00
# 1                            0.10               2                  0.00
# 1                            0.00               1                  0.00
# 1                            0.00               2                  0.00
# ...                           ...             ...                   ...
# 1                            0.55               1                  0.44
# 1                            0.38               1                  0.33
# 1                            0.57               2                  0.00
# 1                            0.57               1                  0.00
# 1                            0.27               1                  0.00
#
#              name==username  description length  external URL  private  \
# profile pic
# ...

# %%
info.drop(labels='external URL', axis=1,inplace=True)

# %%
info.drop(labels='name==username', axis=1,inplace=True)

# %%
info.drop(labels='private', axis=1, inplace=True)

# %%
info
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.27               0                  0.00
# 1              1                  0.00               2                  0.00
# 2              1                  0.10               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.00               2                  0.00
# ..           ...                   ...             ...                   ...
# 571            1                  0.55               1                  0.44
# 572            1                  0.38               1                  0.33
# 573            1                  0.57               2                  0.00
# 574            1                  0.57               1                  0.00
# 575            1                  0.27               1                  0.00
#
# ...

# %%
info.rename(columns = {"profile pic" : "profile_pic", "nums/length fullname" : "fullname_length", "nums/length username":"username_length", "fullname words":"fullname_words", "external URL":"external_URL","#posts":"posts", "#followers":"followers", "#follows":"follows", "nums/legth fullname":"fullname_length","description length":"description_length"}, inplace=True)

# %%
info
# Out:
#      profile_pic  username_length  fullname_words  fullname_length  \
# 0              1             0.27               0             0.00
# 1              1             0.00               2             0.00
# 2              1             0.10               2             0.00
# 3              1             0.00               1             0.00
# 4              1             0.00               2             0.00
# ..           ...              ...             ...              ...
# 571            1             0.55               1             0.44
# 572            1             0.38               1             0.33
# 573            1             0.57               2             0.00
# 574            1             0.57               1             0.00
# 575            1             0.27               1             0.00
#
#      description_length  posts  followers  follows  fake
# 0                    53     32       1000      955     0
# ...

# %%
info[info.profile_pic == 0].describe()
# Out:
#        profile_pic  username_length  fullname_words  fullname_length  \
# count        172.0       172.000000      172.000000       172.000000
# mean           0.0         0.283198        1.116279         0.061337
# std            0.0         0.225613        0.516819         0.161176
# min            0.0         0.000000        0.000000         0.000000
# 25%            0.0         0.045000        1.000000         0.000000
# 50%            0.0         0.300000        1.000000         0.000000
# 75%            0.0         0.440000        1.000000         0.000000
# max            0.0         0.890000        3.000000         1.000000
#
#        description_length       posts    followers      follows        fake
# count          172.000000  172.000000   172.000000   172.000000  172.000000
# mean             1.383721    3.098837   102.662791   234.511628    0.988372
# std              7.230003   15.147099   371.558913   670.443691    0.107517
# ...

# %%
info[(info.profile_pic == 0) & (info.description_length == 0) & (info.posts == 0)].describe()
# Out:
#        profile_pic  username_length  fullname_words  fullname_length  \
# count        123.0       123.000000      123.000000       123.000000
# mean           0.0         0.270407        1.170732         0.043089
# std            0.0         0.220415        0.538780         0.116999
# min            0.0         0.000000        0.000000         0.000000
# 25%            0.0         0.000000        1.000000         0.000000
# 50%            0.0         0.270000        1.000000         0.000000
# 75%            0.0         0.425000        1.000000         0.000000
# max            0.0         0.890000        3.000000         0.500000
#
#        description_length  posts    followers      follows   fake
# count               123.0  123.0   123.000000   123.000000  123.0
# mean                  0.0    0.0   106.804878   212.707317    1.0
# std                   0.0    0.0   432.620506   723.321514    0.0
# min                   0.0    0.0     0.000000     0.000000    1.0
# ...

# %%
info[(info.profile_pic == 0) & (info.description_length == 0) & (info.posts == 0)].count()
# Out:
# profile_pic           123
# username_length       123
# fullname_words        123
# fullname_length       123
# description_length    123
# posts                 123
# followers             123
# follows               123
# fake                  123
# dtype: int64

# %%
info[info.description_length >= 22.623264].describe()
# Out:
#        profile_pic  username_length  fullname_words  fullname_length  \
# count   182.000000       182.000000      182.000000       182.000000
# mean      0.978022         0.056923        1.895604         0.010385
# std       0.147016         0.125840        1.384636         0.052109
# min       0.000000         0.000000        0.000000         0.000000
# 25%       1.000000         0.000000        1.000000         0.000000
# 50%       1.000000         0.000000        2.000000         0.000000
# 75%       1.000000         0.000000        2.000000         0.000000
# max       1.000000         0.830000       12.000000         0.400000
#
#        description_length        posts     followers      follows        fake
# count          182.000000   182.000000  1.820000e+02   182.000000  182.000000
# mean            67.521978   207.131868  1.470678e+05   780.659341    0.109890
# std             38.717807   409.423411  1.082285e+06  1208.091150    0.313616
# ...

# %%
info[info.description_length >= 22.623264]
# Out:
#      profile_pic  username_length  fullname_words  fullname_length  \
# 0              1             0.27               0             0.00
# 1              1             0.00               2             0.00
# 3              1             0.00               1             0.00
# 5              1             0.00               4             0.00
# 6              1             0.00               2             0.00
# ..           ...              ...             ...              ...
# 470            1             0.25               1             0.00
# 544            0             0.27               2             0.00
# 559            1             0.50               1             0.40
# 564            1             0.16               1             0.12
# 570            1             0.20               1             0.00
#
#      description_length  posts  followers  follows  fake
# 0                    53     32       1000      955     0
# ...

# %%
expressive_desc = info[info.description_length >= 22.623264]
sns.displot(expressive_desc['description_length'])

# %%
expressive_desc = info[info.description_length >= 22.623264]
sns.countplot(expressive_desc['description_length'])
# Out:
# C:\Users\manas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='description_length', ylabel='count'>

# %%
info[info.posts == 0].describe()
# Out:
#        profile_pic  username_length  fullname_words  fullname_length  \
# count   157.000000       157.000000      157.000000       157.000000
# mean      0.210191         0.272866        1.140127         0.040573
# std       0.408748         0.223584        0.571308         0.114069
# min       0.000000         0.000000        0.000000         0.000000
# 25%       0.000000         0.060000        1.000000         0.000000
# 50%       0.000000         0.270000        1.000000         0.000000
# 75%       0.000000         0.420000        1.000000         0.000000
# max       1.000000         0.910000        3.000000         0.500000
#
#        description_length  posts    followers      follows        fake
# count          157.000000  157.0   157.000000   157.000000  157.000000
# mean             1.853503    0.0    92.280255   189.254777    0.974522
# std             12.751981    0.0   384.010380   643.110938    0.158075
# ...

# %%
info[info.follows == 7500.000000].describe()
# Out:
#        profile_pic  username_length  fullname_words  fullname_length  \
# count          2.0              2.0         2.00000              2.0
# mean           1.0              0.0         2.50000              0.0
# std            0.0              0.0         2.12132              0.0
# min            1.0              0.0         1.00000              0.0
# 25%            1.0              0.0         1.75000              0.0
# 50%            1.0              0.0         2.50000              0.0
# 75%            1.0              0.0         3.25000              0.0
# max            1.0              0.0         4.00000              0.0
#
#        description_length       posts    followers  follows  fake
# count            2.000000    2.000000     2.000000      2.0   2.0
# mean            90.000000  132.000000  1579.000000   7500.0   0.0
# std             84.852814   41.012193   277.185858      0.0   0.0
# min             30.000000  103.000000  1383.000000   7500.0   0.0
# ...

# %%
info[info.follows == 7500.000000]
# Out:
#      profile_pic  username_length  fullname_words  fullname_length  \
# 130            1              0.0               4              0.0
# 276            1              0.0               1              0.0
#
#      description_length  posts  followers  follows  fake
# 130                 150    161       1383     7500     0
# 276                  30    103       1775     7500     0

# %%
# Efforts By:
# MANASVVI AGGARWAL
