# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
test=pd.read_csv('test.csv')
pd.read_csv('test.csv')
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.33               1                  0.33
# 1              1                  0.00               5                  0.00
# 2              1                  0.00               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.50               1                  0.00
# ..           ...                   ...             ...                   ...
# 115            1                  0.29               1                  0.00
# 116            1                  0.40               1                  0.00
# 117            1                  0.00               2                  0.00
# 118            0                  0.17               1                  0.00
# 119            1                  0.44               1                  0.00
#
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   profile pic           120 non-null    int64
#  1   nums/length username  120 non-null    float64
#  2   fullname words        120 non-null    int64
#  3   nums/length fullname  120 non-null    float64
#  4   name==username        120 non-null    int64
#  5   description length    120 non-null    int64
#  6   external URL          120 non-null    int64
#  7   private               120 non-null    int64
#  8   #posts                120 non-null    int64
#  9   #followers            120 non-null    int64
#  10  #follows              120 non-null    int64
#  11  fake                  120 non-null    int64
# dtypes: float64(2), int64(10)
# memory usage: 11.4 KB

# %%
test.isnull()
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0          False                 False           False                 False
# 1          False                 False           False                 False
# 2          False                 False           False                 False
# 3          False                 False           False                 False
# 4          False                 False           False                 False
# ..           ...                   ...             ...                   ...
# 115        False                 False           False                 False
# 116        False                 False           False                 False
# 117        False                 False           False                 False
# 118        False                 False           False                 False
# 119        False                 False           False                 False
#
# ...

# %%
sns.heatmap(test.isnull())
# Out:
# <AxesSubplot:>

# %%
y=test.drop(columns=['nums/length username','fullname words','nums/length fullname','external URL','private'])

# %%
# Q1. Determine the maximum no. of followers possesed by a user belonging to the group of the user with no profile pic.

# %%
x=y[ y['profile pic'] == 0 ]
x
# Out:
#      profile pic  name==username  description length  #posts  #followers  \
# 60             0               0                   0       0           0
# 62             0               0                   0       0          19
# 63             0               1                   0       0          69
# 64             0               0                   0       0          22
# 65             0               0                   0       0          31
# 66             0               0                   0       0           9
# 67             0               1                   0       0          69
# 68             0               0                   0       0          23
# 69             0               0                   0       1          17
# 70             0               0                  14       0          46
# 71             0               0                   0       0          16
# 72             0               0                   0       0           0
# ...

# %%
print( 'Maximum no. of followers possed by a user belonging to the group of user with no profile pic: ')
print(x['#followers'].max() )
# Out:
# Maximum no. of followers possed by a user belonging to the group of user with no profile pic:
# 2997

# %%
# Q2. Determine the number of dead account, if they exist.

# %%
print("Total number of dead account:")
x[ (x['#posts']==0) &(x['description length']==0) ].shape[0]
# Out:
# Total number of dead account:
# 21

# %%
# Q3. Find out how expressive a person is on Instagram based on the length of the bio.
# (An expressive person can be defined as the user whose description length exceeds the average.)

# %%
y.describe()
# Mean/Average of the description length is 27.200000
# Out:
#        profile pic  name==username  description length       #posts  \
# count   120.000000      120.000000          120.000000   120.000000
# mean      0.758333        0.041667           27.200000    82.866667
# std       0.429888        0.200664           42.588632   230.468136
# min       0.000000        0.000000            0.000000     0.000000
# 25%       1.000000        0.000000            0.000000     1.000000
# 50%       1.000000        0.000000            0.000000     8.000000
# 75%       1.000000        0.000000           45.250000    58.250000
# max       1.000000        1.000000          149.000000  1879.000000
#
#          #followers     #follows        fake
# count  1.200000e+02   120.000000  120.000000
# mean   4.959472e+04   779.266667    0.500000
# std    3.816126e+05  1409.383558    0.502096
# min    0.000000e+00     1.000000    0.000000
# 25%    6.725000e+01   119.250000    0.000000
# 50%    2.165000e+02   354.500000    0.500000
# ...

# %%
w=y[ y['description length']>27.20000]
w
# Out:
#      profile pic  name==username  description length  #posts  #followers  \
# 0              1               1                  30      35         488
# 1              1               0                  64       3          35
# 2              1               0                  82     319         328
# 3              1               0                 143     273       14890
# 4              1               0                  76       6         225
# 6              1               0                 132       9         213
# 8              1               0                  96      17         122
# 9              1               0                  78       9         834
# 11             1               0                  78      97        1913
# 12             1               0                  61      17         200
# 13             1               0                  45       8         130
# 14             1               0                  43      60         192
# ...

# %%
y[ y['description length']>27.20000].shape[0]
# Out:
# 37

# %%
sns.distplot( w['description length'],bins=20)
# Out:
# C:\Users\lipik\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='description length', ylabel='Density'>

# %%
print("Percentage of people who are expressive= ")
print(37/120*100)
# Out:
# Percentage of people who are expressive=
# 30.833333333333336

# %%
# Q4. Detemine the maximumm no. of followers possessed by a user among those who have 0 posts on their respective account.

# %%
f=y[ y['#posts']==0 ]
f
# Out:
#      profile pic  name==username  description length  #posts  #followers  \
# 20             1               0                   0       0         189
# 47             1               0                   0       0          87
# 60             0               0                   0       0           0
# 61             1               0                   0       0          45
# 62             0               0                   0       0          19
# 63             0               1                   0       0          69
# 64             0               0                   0       0          22
# 65             0               0                   0       0          31
# 66             0               0                   0       0           9
# 67             0               1                   0       0          69
# 68             0               0                   0       0          23
# 70             0               0                  14       0          46
# ...

# %%
print("Total number of followers possessed by a user among those who have 0 posts on their respective account:")
print(f['#followers'].max() )
# Out:
# Total number of followers possessed by a user among those who have 0 posts on their respective account:
# 2997

# %%
# Q5. What is the ratio of number of followers(#followers) to number of following(#follows) 
# for the user with the maximum number of following?

# %%
y['#follows'].max()
# Out:
# 7453

# %%
y.sort_values(by='#follows')
# Out:
#      profile pic  name==username  description length  #posts  #followers  \
# 73             0               0                   0       0          21
# 71             0               0                   0       0          16
# 75             0               0                   0       1          24
# 60             0               0                   0       0           0
# 1              1               0                  64       3          35
# ..           ...             ...                 ...     ...         ...
# 29             1               0                 147    1879     4021842
# 82             1               0                   0       3        1789
# 86             1               0                  58       4        1742
# 3              1               0                 143     273       14890
# 102            0               0                   0       2        1987
#
#      #follows  fake
# 73          1     1
# 71          2     1
# 75          2     1
# ...

# %%
# From sorted y table, we can see the last row has the max. no. of #follows.
print("Ratio of number of followers(#followers) to number of following(#follows): ")
print(1987/7453)
# Out:
# Ratio of number of followers(#followers) to number of following(#follows):
# 0.2666040520595733
