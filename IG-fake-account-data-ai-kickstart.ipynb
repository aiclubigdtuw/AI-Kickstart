# %% [markdown]
# # EVALUATORY ASSIGNMENT
# <h4 align="right">by Shivam Sharma</h4>
#
#
# Our data is :*instagram-fake-spammer-genuine-accounts*
# We will do the follows: -
# <h4 align="center"> <b>Data Analysis</b>
# <h4 align="center"> <b>Data processing and Visualization</b> </h4>

# %% [markdown]
# We will first import the necessory libraries for data processing and visualization.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import warnings
warnings.filterwarnings('ignore')
# Out:
# /kaggle/input/instagram-fake-spammer-genuine-accounts/train.csv
# /kaggle/input/instagram-fake-spammer-genuine-accounts/test.csv

# %% [markdown]
# ### Are we upto date, on the library versions?

# %%
print(' PANDAS: -',pd.__version__,'\n NUMPY: -',np.__version__,'\n SEABORN: -',sns.__version__)
# Out:
#  PANDAS: - 1.2.2
#  NUMPY: - 1.19.5
#  SEABORN: - 0.11.1

# %% [markdown]
# # <center>1. DATA ANALYSIS</center>
# <hr>

# %% [markdown]
# ### Now We start by loading our data!
# ### Our data contains
#  Train.csv and Test.csv

# %%
data_train = pd.read_csv('../input/instagram-fake-spammer-genuine-accounts/train.csv')
data_test = pd.read_csv('../input/instagram-fake-spammer-genuine-accounts/test.csv')

# %% [markdown]
# Lets see the data now

# %%
data_train.head()
# Out:
#    profile pic  nums/length username  fullname words  nums/length fullname  \
# 0            1                  0.27               0                   0.0
# 1            1                  0.00               2                   0.0
# 2            1                  0.10               2                   0.0
# 3            1                  0.00               1                   0.0
# 4            1                  0.00               2                   0.0
#
#    name==username  description length  external URL  private  #posts  \
# 0               0                  53             0        0      32
# 1               0                  44             0        0     286
# 2               0                   0             0        1      13
# 3               0                  82             0        0     679
# 4               0                   0             0        1       6
#
#    #followers  #follows  fake
# 0        1000       955     0
# 1        2740       533     0
# ...

# %%
print(np.shape(data_train),np.shape(data_test)) #shows the shapes
# Out:
# (576, 12) (120, 12)

# %%
data_train.isnull().any() #non of the values contain any null value
# Out:
# profile pic             False
# nums/length username    False
# fullname words          False
# nums/length fullname    False
# name==username          False
# description length      False
# external URL            False
# private                 False
# #posts                  False
# #followers              False
# #follows                False
# fake                    False
# dtype: bool

# %% [markdown]
# # <center>2. DATA PROCESSING AND VISUALIZATION</center>
# <hr>

# %% [markdown]
# ### 1. Thus max number of followers possessed by a user belonging to the group of users with no profile picture

# %%
plt.figure(figsize=(25, 25))

sns.countplot(x="#followers", data=data_train,hue="profile pic")
# Out:
# <AxesSubplot:xlabel='#followers', ylabel='count'>

# %% [markdown]
# ## We can infer that the accounts with more number of followers mostly have Profile Pictures to their profiles!
#
# >Well, we cannot land to any conclusion with this data visualization.
#     lets try to compute plots in smaller intervals and see if we could find any relevant information.

# %%
##Max no. of followers by a user belonging to non profile picture category
data_follower_under_10000000 = data_train[data_train["#followers"]< 10000000] #under 10M
data_follower_under_1000000 = data_train[data_train["#followers"]< 1000000]#under 1M
data_follower_under_100000 = data_train[data_train["#followers"]< 100000]#under 1 lakhs
data_follower_under_10000 = data_train[data_train["#followers"]< 10000] #under 10 k
data_follower_under_1000 = data_train[data_train["#followers"]< 1000] #under 1k
data_follower_under_100 = data_train[data_train["#followers"]< 100] #under 100 

data_follower_bewtween_10000000_1000000 = data_train[(data_train["#followers"]>1000000) & (data_train["#followers"]< 10000000)]#bewtween_10000000_1000000
data_follower_bewtween_1000000_100000 = data_train[(data_train["#followers"]>100000) & (data_train["#followers"]< 1000000)]#bewtween_1000000_100000
data_follower_bewtween_100000_10000 = data_train[(data_train["#followers"]>10000) & (data_train["#followers"]< 100000)] #bewtween_100000_10000
data_follower__bewtween_10000_1000 = data_train[(data_train["#followers"]>1000) & (data_train["#followers"]< 10000)] #bewtween_10000_1000
data_follower_bewtween_100_1000 = data_train[(data_train["#followers"]>100) & (data_train["#followers"]< 1000)]  #bewtween_100_1000

# Now making plots
fig, axes = plt.subplots(11, 2, figsize=(18,20), sharey=False)
fig.suptitle('Distribution of People with or without profile picture according to #Followers. \n',size=30)

axes[0][0].set_title("under 10000000",size=12)
axes[1][0].set_title("under 1000000",size=12)
axes[2][0].set_title("under 100000",size=12)
axes[3][0].set_title("under 10000",size=12)
axes[4][0].set_title("under 1000",size=12)
axes[5][0].set_title("under 100",size=12)
axes[6][0].set_title("Between 10000000_1000000",size=12)
axes[7][0].set_title("Between 1000000_100000 ",size=12)
axes[8][0].set_title("Between 100000_10000",size=12)
axes[9][0].set_title("Between 10000_1000 ",size=12)
axes[10][0].set_title("Between 100_1000",size=12)

sns.boxplot(ax=axes[0][0], data=data_follower_under_10000000 ,x="#followers",y="profile pic",orient='h',palette="Set2")
sns.boxplot(ax=axes[1][0], data=data_follower_under_1000000 ,x="#followers",y="profile pic",orient='h',palette="Set1")
sns.boxplot(ax=axes[2][0], data=data_follower_under_100000 ,x="#followers",y="profile pic",orient='h',palette="Set2")
sns.boxplot(ax=axes[3][0], data=data_follower_under_10000 ,x="#followers",y="profile pic",orient='h',palette="Set1")
sns.boxplot(ax=axes[4][0], data=data_follower_under_1000 ,x="#followers",y="profile pic",orient='h',palette="Set2")
sns.boxplot(ax=axes[5][0], data=data_follower_under_100 ,x="#followers",y="profile pic",orient='h',palette="Set1")
sns.boxplot(ax=axes[6][0], data=data_follower_bewtween_10000000_1000000 ,x="#followers",y="profile pic",orient='h',palette="Set2")
sns.boxplot(ax=axes[7][0], data=data_follower_bewtween_1000000_100000 ,x="#followers",y="profile pic",orient='h',palette="Set1")
sns.boxplot(ax=axes[8][0], data=data_follower_bewtween_100000_10000 ,x="#followers",y="profile pic",orient='h',palette="Set2")
sns.boxplot(ax=axes[9][0], data=data_follower__bewtween_10000_1000 ,x="#followers",y="profile pic",orient='h',palette="Set1")
sns.boxplot(ax=axes[10][0], data=data_follower_bewtween_100_1000 ,x="#followers",y="profile pic",orient='h',palette="Set2",dodge =False,width=.2)
sns.swarmplot(ax=axes[0][1], data=data_follower_under_10000000 ,x="#followers",y="profile pic",orient='h',hue="profile pic",palette="Set2")
sns.swarmplot(ax=axes[1][1], data=data_follower_under_1000000 ,x="#followers",y="profile pic",orient='h',hue="profile pic",palette="Set1")
sns.swarmplot(ax=axes[2][1], data=data_follower_under_100000 ,x="#followers",y="profile pic",orient='h',hue="profile pic",palette="Set2")
sns.swarmplot(ax=axes[3][1], data=data_follower_under_10000 ,x="#followers",y="profile pic",orient='h',hue="profile pic",palette="Set1")
sns.swarmplot(ax=axes[4][1], data=data_follower_under_1000 ,x="#followers",y="profile pic",orient='h',hue="profile pic",palette="Set2")
sns.swarmplot(ax=axes[5][1], data=data_follower_under_100 ,x="#followers",y="profile pic",orient='h',hue="profile pic",palette="Set1")
sns.swarmplot(ax=axes[6][1], data=data_follower_bewtween_10000000_1000000 ,x="#followers",y="profile pic",orient='h',hue="profile pic",palette="Set2")
sns.swarmplot(ax=axes[7][1], data=data_follower_bewtween_1000000_100000 ,x="#followers",y="profile pic",orient='h',hue="profile pic",palette="Set1")
sns.swarmplot(ax=axes[8][1], data=data_follower_bewtween_100000_10000 ,x="#followers",y="profile pic",orient='h',hue="profile pic",palette="Set2")
sns.swarmplot(ax=axes[9][1], data=data_follower__bewtween_10000_1000 ,x="#followers",y="profile pic",orient='h',hue="profile pic",palette="Set1")
sns.swarmplot(ax=axes[10][1], data=data_follower_bewtween_100_1000 ,x="#followers",y="profile pic",orient='h',hue="profile pic",palette="Set2")

fig.tight_layout()

# %% [markdown]
# ## What could be infered from this ?
#
# > These plots validate the fact that as #followers increases the number of accounts without profile picture decreases.
#
# Now we can say that the account with greatest value of followers without profile will be near lower values of #followers
#
# We query our data to get the max number of followers possessed by a user belonging to the group of users with no profile picture.

# %%
print("Thus max number of followers possessed by a user belonging to the group of users with no profile picture =>",data_train[data_train['profile pic']==0]['#followers'].max()) # no profile pic and the maximum followers
# Out:
# Thus max number of followers possessed by a user belonging to the group of users with no profile picture => 3033

# %% [markdown]
# ### Lets check out the whole row of that person/people with 3033 followers and having no profile picture.

# %%
data_train[data_train["#followers"] == 3033] #also check there are no multpile accounts under same constraint!
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 530            0                  0.18               1                   0.0
#
#      name==username  description length  external URL  private  #posts  \
# 530               0                   0             0        0       0
#
#      #followers  #follows  fake
# 530        3033      1155     1

# %% [markdown]
# What about the account with profile pictures, lets check on that list for max followers

# %%
print("We get to know that => Followers are",data_train[data_train['profile pic']==1]['#followers'].max())
# Out:
# We get to know that => Followers are 15338538

# %% [markdown]
# Both the queries results can be easily validated from the above charts of #followers with or without profile picture.

# %% [markdown]
# ### 2. <u>Dead accounts</u> are represented by their numeber of posts, description length and if they have a profile picture or not. Using the same structure for querying we can get number of dead accounts from our data set(train data set).

# %%
data_train[(data_train['profile pic']==0)&(data_train['#posts']==0)&(data_train['description length']==0)]
# No profile picture,  No posts and a zero description length.
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 288            0                  0.22               1                  0.00
# 289            0                  0.38               1                  0.00
# 293            0                  0.31               2                  0.00
# 295            0                  0.00               1                  0.00
# 297            0                  0.00               2                  0.00
# ..           ...                   ...             ...                   ...
# 552            0                  0.46               1                  0.00
# 553            0                  0.73               1                  0.00
# 556            0                  0.31               1                  0.31
# 561            0                  0.86               2                  0.18
# 562            0                  0.62               1                  0.00
#
# ...

# %%
dead_acc = data_train[(data_train['profile pic']==0)&(data_train['#posts']==0)&(data_train['description length']==0)].shape[0]
print("The number of dead accounts according to our constraint are ->",dead_acc)
# Out:
# The number of dead accounts according to our constraint are -> 123

# %% [markdown]
# ### We can also infer something if we try to visualise the data with fake accounts :
# > We see that a dead account has higher probability of being a fake account!

# %%
ax = sns.barplot(x="is_dead", y="fake", data=data_trainning) 
#This shows that a dead account has higher probability of being a fake account!

# %% [markdown]
# ## This shows that a dead account has higher probability of being a fake account!

# %% [markdown]
# ## 3. An expressive or an non-expressive user?
#
# An user is said to be expreessive if he/she has a description length above then average, but first we need to know about the average value of a description length from our data.
#
# So we use .describe method

# %%
data_train.describe()
# Out:
#        profile pic  nums/length username  fullname words  \
# count   576.000000            576.000000      576.000000
# mean      0.701389              0.163837        1.460069
# std       0.458047              0.214096        1.052601
# min       0.000000              0.000000        0.000000
# 25%       0.000000              0.000000        1.000000
# 50%       1.000000              0.000000        1.000000
# 75%       1.000000              0.310000        2.000000
# max       1.000000              0.920000       12.000000
#
#        nums/length fullname  name==username  description length  external URL  \
# count            576.000000      576.000000          576.000000    576.000000
# mean               0.036094        0.034722           22.623264      0.116319
# std                0.125121        0.183234           37.702987      0.320886
# min                0.000000        0.000000            0.000000      0.000000
# ...

# %% [markdown]
# ## --More clearly the mean is --

# %%
data_train['description length'].mean(axis=0)
# Out:
# 22.62326388888889

# %% [markdown]
# > We get to know that the average length of an instagram bio should be greater than 22 words, max is 150 words and min is 0 words. Taking this as our basis we can divide our data into : non-expressive if desc_len is in between 0- 22 and expressive if desc_len is in between 22-150.

# %%
data_exp_non_exp = data_train
data_exp_non_exp["Expressive?"] = np.where(data_exp_non_exp['description length'] >22,'Expressive','Non-Expressive')

# %%
data_exp_non_exp
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.27               0                  0.00
# 1              1                  0.00               2                  0.00
# 2              1                  0.10               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.00               2                  0.00
# ..           ...                   ...             ...                   ...
# 571            1                  0.55               1                  0.44
# 572            1                  0.38               1                  0.33
# 573            1                  0.57               2                  0.00
# 574            1                  0.57               1                  0.00
# 575            1                  0.27               1                  0.00
#
# ...

# %%
data_exp_non_exp[data_exp_non_exp["Expressive?"] == "Expressive"].shape
# Out:
# (182, 13)

# %% [markdown]
# ### Thus 182 people arefound to be more expressive then the average.

# %%
fig, axes = plt.subplots(2, 2, figsize=(18,20), sharey=False)
fig.suptitle('The coorelation of expressiveness of an user depending upon- Desc_len, fake, private, no. of posts \n',size=15)


sns.barplot(ax=axes[0][0] ,x="Expressive?",y="description length",hue="Expressive?",data=data_exp_non_exp,palette="Set2")
sns.barplot(ax=axes[1][1] ,x="Expressive?",y="fake",hue="Expressive?",data=data_exp_non_exp,palette="Set2")
sns.barplot(ax=axes[1][0] ,x="Expressive?",y="private",hue="Expressive?",data=data_exp_non_exp,palette="Set2")
sns.barplot(ax=axes[0][1] ,x="Expressive?",y="#posts",hue="Expressive?",data=data_exp_non_exp,palette="Set2")
# Out:
# <AxesSubplot:xlabel='Expressive?', ylabel='#posts'>

# %% [markdown]
# ### From this representation we see that if a person is expressive he/she also has more number of posts, is lower chances of having account private and also lower chances of being a fake user.

# %% [markdown]
# ## 4. Max no. of followers possessed by a user among those who have 0 posts.

# %%
data_train[data_train['#posts']==0]['#followers'].max()
# Out:
# 3033

# %% [markdown]
# ## 5. Ratio of number of followers (#followers) to number of following (#follows) for the user with the maximum number of following

# %%
data_train['#follows'].max() #the row/user for which there is max number of followers
# Out:
# 7500

# %%
data_followers = data_train[data_train['#follows']==7500] # lets check if there are multpile entries.

# %%
data_followers
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 130            1                   0.0               4                   0.0
# 276            1                   0.0               1                   0.0
#
#      name==username  description length  external URL  private  #posts  \
# 130               0                 150             1        0     161
# 276               0                  30             0        1     103
#
#      #followers  #follows  fake Expressive?
# 130        1383      7500     0  Expressive
# 276        1775      7500     0  Expressive

# %%
print("for user 130--> ratio is : ", 1383/7500)
print("for user 276--> ratio is : ", 1775/7500)
# Out:
# for user 130--> ratio is :  0.1844
# for user 276--> ratio is :  0.23666666666666666

# %%
sns.barplot(ax=axes[1][1] ,x="#posts",y="fake",hue="#posts",data=data_exp_non_exp,palette="Set2")
sns.barplot(ax=axes[1][0] ,x="#posts",y="private",hue="#posts",data=data_exp_non_exp,palette="Set2")
sns.barplot(ax=axes[0][1] ,x="#posts",y="Expressive?",hue="#posts",data=data_exp_non_exp,palette="Set2")

# %% [markdown]
# # THANK YOU
