# %% [markdown]
# <a href="https://colab.research.google.com/github/Charanjeev-2k2/AI-Kickstart/blob/main/Pok%C3%A9mon_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("pokemon.csv")

# %% [markdown]
# #EDA

# %%
train.shape
# Out:
# (304, 30001)

# %%
train
# Out:
#        0    1    2    3    4  ...  29996  29997  29998  29999      target
# 0     37  106  111   37  106  ...    111     37    106    111  Charmander
# 1    255  255  255  255  255  ...    255    255    255    255  Charmander
# 2    103  244   68   91  234  ...     53    123    255     74     Pikachu
# 3    255  255  255  255  255  ...    255    255    255    255     Pikachu
# 4      0    0    0    0    0  ...      0      0      0      0   Bulbasaur
# ..   ...  ...  ...  ...  ...  ...    ...    ...    ...    ...         ...
# 299    9   65   17    9   65  ...    118     73    184    155   Bulbasaur
# 300  255  255  255  255  255  ...    255    255    255    255     Pikachu
# 301    0    6    6    1    7  ...    145    118    119    120     Pikachu
# 302  255  250  247  255  250  ...    217    255    186    191     Pikachu
# 303  255  255  255  255  255  ...    197    252    252    252  Charmander
#
# [304 rows x 30001 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Columns: 30001 entries, 0 to target
# dtypes: int64(30000), object(1)
# memory usage: 69.6+ MB

# %%
train.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 29996     0
# 29997     0
# 29998     0
# 29999     0
# target    0
# Length: 30001, dtype: int64

# %%
sns.heatmap(train.isnull(), yticklabels=False, cbar=False, cmap="viridis")

# %% [markdown]
# Defining feature and Label

# %%
y = train["target"].values
y.shape
# Out:
# (304,)

# %%
X = train.drop(columns = ["target"], inplace = False)
X = X.values
X.shape
# Out:
# (304, 30000)

# %%
plt.imshow(X[5].reshape(100,100,3))

# %%
#Splitting Data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state = 0)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (243, 30000) (243,)
# (61, 30000) (61,)

# %% [markdown]
# #Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
DTmodel = DecisionTreeClassifier()

# %%
DTmodel.fit(X_train, y_train)
y_pred_DT = DTmodel.predict(X_test)
y_pred_DT
# Out:
# array(['Bulbasaur', 'Pikachu', 'Charmander', 'Charmander', 'Bulbasaur',
#        'Bulbasaur', 'Pikachu', 'Pikachu', 'Bulbasaur', 'Pikachu',
#        'Bulbasaur', 'Pikachu', 'Pikachu', 'Charmander', 'Charmander',
#        'Pikachu', 'Bulbasaur', 'Charmander', 'Pikachu', 'Charmander',
#        'Charmander', 'Bulbasaur', 'Charmander', 'Charmander', 'Bulbasaur',
#        'Bulbasaur', 'Charmander', 'Pikachu', 'Bulbasaur', 'Pikachu',
#        'Pikachu', 'Charmander', 'Charmander', 'Charmander', 'Pikachu',
#        'Bulbasaur', 'Charmander', 'Charmander', 'Charmander', 'Pikachu',
#        'Charmander', 'Bulbasaur', 'Pikachu', 'Charmander', 'Bulbasaur',
#        'Charmander', 'Bulbasaur', 'Charmander', 'Bulbasaur', 'Charmander',
#        'Bulbasaur', 'Charmander', 'Charmander', 'Charmander', 'Bulbasaur',
#        'Pikachu', 'Charmander', 'Pikachu', 'Bulbasaur', 'Pikachu',
#        'Charmander'], dtype=object)

# %% [markdown]
# *Decision Tree Score*

# %%
DTmodel.score(X_test, y_test)
# Out:
# 0.8032786885245902

# %% [markdown]
# *Prediction and Comparison*

# %%
for i in [2, 6, 8, 10 , 23, 60, 56, 49]:
  random_img = X_test[i]
  plt.imshow(random_img.reshape(100,100,3))
  plt.show()
  print("Actual Label: ", y_test[i])
  p = DTmodel.predict([random_img])
  print("Predicted Label: ", p)
# Out:
# Actual Label:  Charmander
# Predicted Label:  ['Charmander']
# Actual Label:  Pikachu
# Predicted Label:  ['Pikachu']
# Actual Label:  Pikachu
# Predicted Label:  ['Bulbasaur']
# Actual Label:  Pikachu
# Predicted Label:  ['Bulbasaur']
# Actual Label:  Charmander
# Predicted Label:  ['Charmander']
# Actual Label:  Charmander
# Predicted Label:  ['Charmander']
# Actual Label:  Bulbasaur
# Predicted Label:  ['Charmander']
# Actual Label:  Charmander
# Predicted Label:  ['Charmander']

# %% [markdown]
# #KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
KNNmodel = KNeighborsClassifier(n_neighbors = 17)

# %%
KNNmodel.fit(X_train, y_train)
y_pred_KNN = KNNmodel.predict(X_test)
y_pred_KNN
# Out:
# array(['Bulbasaur', 'Pikachu', 'Charmander', 'Charmander', 'Bulbasaur',
#        'Bulbasaur', 'Bulbasaur', 'Pikachu', 'Pikachu', 'Pikachu',
#        'Pikachu', 'Bulbasaur', 'Charmander', 'Charmander', 'Charmander',
#        'Pikachu', 'Bulbasaur', 'Charmander', 'Charmander', 'Charmander',
#        'Bulbasaur', 'Bulbasaur', 'Charmander', 'Charmander', 'Bulbasaur',
#        'Bulbasaur', 'Charmander', 'Pikachu', 'Bulbasaur', 'Pikachu',
#        'Bulbasaur', 'Bulbasaur', 'Charmander', 'Charmander', 'Pikachu',
#        'Bulbasaur', 'Bulbasaur', 'Charmander', 'Pikachu', 'Pikachu',
#        'Charmander', 'Bulbasaur', 'Pikachu', 'Charmander', 'Bulbasaur',
#        'Charmander', 'Bulbasaur', 'Charmander', 'Bulbasaur', 'Pikachu',
#        'Bulbasaur', 'Charmander', 'Charmander', 'Charmander', 'Bulbasaur',
#        'Charmander', 'Bulbasaur', 'Pikachu', 'Bulbasaur', 'Pikachu',
#        'Charmander'], dtype=object)

# %% [markdown]
# *KNN Score*

# %%
KNNmodel.score(X_test, y_test)
# Out:
# 0.8360655737704918

# %% [markdown]
# *Prediction and Comparison*

# %%
for i in [2, 6, 8, 10 , 23, 60, 56, 49]:
  random_img = X_test[i]
  plt.imshow(random_img.reshape(100,100,3))
  plt.show()
  print("Actual Label: ", y_test[i])
  p = KNNmodel.predict([random_img])
  print("Predicted Label: ", p)
# Out:
# Actual Label:  Charmander
# Predicted Label:  ['Charmander']
# Actual Label:  Pikachu
# Predicted Label:  ['Bulbasaur']
# Actual Label:  Pikachu
# Predicted Label:  ['Pikachu']
# Actual Label:  Pikachu
# Predicted Label:  ['Pikachu']
# Actual Label:  Charmander
# Predicted Label:  ['Charmander']
# Actual Label:  Charmander
# Predicted Label:  ['Charmander']
# Actual Label:  Bulbasaur
# Predicted Label:  ['Bulbasaur']
# Actual Label:  Charmander
# Predicted Label:  ['Pikachu']

# %% [markdown]
# #Logistic Regression

# %% [markdown]
# One vs all classification for multiclass problem

# %%
from sklearn.linear_model import LogisticRegression
LRmodel = LogisticRegression()

# %%
LRmodel.fit(X_train, y_train)
y_predict_LR = LRmodel.predict(X_test)
y_predict_LR
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# array(['Bulbasaur', 'Pikachu', 'Charmander', 'Charmander', 'Bulbasaur',
#        'Bulbasaur', 'Pikachu', 'Pikachu', 'Pikachu', 'Pikachu', 'Pikachu',
#        'Pikachu', 'Pikachu', 'Charmander', 'Charmander', 'Pikachu',
#        'Bulbasaur', 'Charmander', 'Charmander', 'Pikachu', 'Bulbasaur',
#        'Bulbasaur', 'Charmander', 'Charmander', 'Bulbasaur', 'Bulbasaur',
#        'Charmander', 'Pikachu', 'Bulbasaur', 'Charmander', 'Bulbasaur',
# ...

# %% [markdown]
# *Logistic Regression Score*

# %%
LRmodel.score(X_test, y_test)
# Out:
# 0.9836065573770492

# %% [markdown]
# *Prediction and Comparison*

# %%
for i in [2, 6, 8, 10 , 23, 60, 56, 49]:
  random_img = X_test[i]
  plt.imshow(random_img.reshape(100,100,3))
  plt.show()
  print("Actual Label: ", y_test[i])
  p = LRmodel.predict([random_img])
  print("Predicted Label: ", p)
# Out:
# Actual Label:  Charmander
# Predicted Label:  ['Charmander']
# Actual Label:  Pikachu
# Predicted Label:  ['Pikachu']
# Actual Label:  Pikachu
# Predicted Label:  ['Pikachu']
# Actual Label:  Pikachu
# Predicted Label:  ['Pikachu']
# Actual Label:  Charmander
# Predicted Label:  ['Charmander']
# Actual Label:  Charmander
# Predicted Label:  ['Charmander']
# Actual Label:  Bulbasaur
# Predicted Label:  ['Bulbasaur']
# Actual Label:  Charmander
# Predicted Label:  ['Charmander']

# %% [markdown]
# #Conclusion

# %% [markdown]
# Decision Tree Score is the least (0.7868)  and Logistic Regression (0.9836) score is max
# Thus, for given data Logistic Regression model is the best
# ---
